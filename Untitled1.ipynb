# %% [markdown]
# <a href="https://colab.research.google.com/github/Anup-Sarkar-DD/GoogleColab_repo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os

# %%
df = pd.read_csv('/content/Tesla_Nasdaq_Prediction.csv')

# %%
df.head()
# Out:
#        Date  Close/Last    Volume     Open     High      Low
# 0  4/8/2022     1025.49  18337900  1043.21  1048.44  1022.44
# 1  4/7/2022     1057.26  26482350  1052.39  1076.59  1021.54
# 2  4/6/2022     1045.76  29782850  1073.47  1079.00  1027.70
# 3  4/5/2022     1091.26  26691670  1136.30  1152.87  1087.30
# 4  4/4/2022     1145.45  27392570  1089.38  1149.91  1072.53

# %%
x = df.iloc[:,2:]

# %%
y = df['Close/Last']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2 , random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train = x_train.reshape(x_train.shape[0], 1, x_train.shape[1]) #reshaped with time step 1 example (samples, time step , features )
x_test = x_test.reshape(x_test.shape[0], 1, x_test.shape[1])

# %%
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)
y_train = scaler.fit_transform(y_train.reshape(-1,1))
y_test = scaler.transform(y_test.reshape(-1,1))

# %%
from keras.models import Sequential
from keras.layers import Dense , SimpleRNN , Dropout

# %%
model = Sequential()
model.add(SimpleRNN(256,input_shape = (x_train.shape[1],x_train.shape[2]),return_sequences = True))
model.add(Dropout(0.20))
model.add(SimpleRNN(128,return_sequences = True))
model.add(Dropout(0.20))
model.add(SimpleRNN(64,return_sequences = True))
model.add(Dropout(0.20))
model.add(Dense(1))

# %%
#compile the model
model.compile(loss = 'mse', optimizer='adam', metrics=['accuracy'])

summary = model.summary()

summary
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 1, 256)         │        66,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 1, 128)         │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 1, 64)          │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1, 1)           │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 128,513 (502.00 KB)
#  Trainable params: 128,513 (502.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#train the model
cont1 = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

pd.DataFrame(cont1.history)['accuracy'].plot(figsize=(6,2))
plt.title("accuary impovement with epoch")
plt.show()
# Out:
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.0000e+00 - loss: 0.2674 - val_accuracy: 0.0000e+00 - val_loss: 0.0123
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0583 - val_accuracy: 0.0000e+00 - val_loss: 0.0095
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0426 - val_accuracy: 0.0000e+00 - val_loss: 0.0177
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0364 - val_accuracy: 0.0000e+00 - val_loss: 0.0043
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0350 - val_accuracy: 0.0000e+00 - val_loss: 0.0082
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0274 - val_accuracy: 0.0000e+00 - val_loss: 0.0038
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 0.0289 - val_accuracy: 0.0000e+00 - val_loss: 0.0115
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0368 - val_accuracy: 0.0000e+00 - val_loss: 0.0050
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0268 - val_accuracy: 0.0000e+00 - val_loss: 0.0056
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0267 - val_accuracy: 0.0000e+00 - val_loss: 0.0169
# Epoch 11/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0294 - val_accuracy: 0.0000e+00 - val_loss: 0.0036
# Epoch 12/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0215 - val_accuracy: 0.0000e+00 - val_loss: 0.0043
# Epoch 13/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0196 - val_accuracy: 0.0000e+00 - val_loss: 0.0056
# Epoch 14/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0205 - val_accuracy: 0.0000e+00 - val_loss: 0.0080
# Epoch 15/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0220 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 16/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0190 - val_accuracy: 0.0000e+00 - val_loss: 0.0054
# Epoch 17/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0206 - val_accuracy: 0.0000e+00 - val_loss: 0.0464
# Epoch 18/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0312 - val_accuracy: 0.0000e+00 - val_loss: 0.0025
# Epoch 19/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0152 - val_accuracy: 0.0000e+00 - val_loss: 0.0023
# Epoch 20/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0243 - val_accuracy: 0.0000e+00 - val_loss: 0.0032
# Epoch 21/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0206 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 22/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0144 - val_accuracy: 0.0000e+00 - val_loss: 0.0036
# Epoch 23/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0174 - val_accuracy: 0.0000e+00 - val_loss: 0.0022
# Epoch 24/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0151 - val_accuracy: 0.0000e+00 - val_loss: 0.0050
# Epoch 25/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0156 - val_accuracy: 0.0000e+00 - val_loss: 0.0041
# Epoch 26/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0161 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 27/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0131 - val_accuracy: 0.0000e+00 - val_loss: 0.0014
# Epoch 28/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 29/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 30/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0128 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 31/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0183 - val_accuracy: 0.0000e+00 - val_loss: 0.0043
# Epoch 32/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0180 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 33/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0143 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 34/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0172 - val_accuracy: 0.0000e+00 - val_loss: 0.0099
# Epoch 35/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0185 - val_accuracy: 0.0000e+00 - val_loss: 0.0033
# Epoch 36/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0167 - val_accuracy: 0.0000e+00 - val_loss: 0.0035
# Epoch 37/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0143 - val_accuracy: 0.0000e+00 - val_loss: 0.0040
# Epoch 38/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0146 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 39/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0143 - val_accuracy: 0.0000e+00 - val_loss: 0.0133
# Epoch 40/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0164 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 41/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0126 - val_accuracy: 0.0000e+00 - val_loss: 0.0040
# Epoch 42/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0175 - val_accuracy: 0.0000e+00 - val_loss: 0.0069
# Epoch 43/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0156 - val_accuracy: 0.0000e+00 - val_loss: 0.0032
# Epoch 44/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0137 - val_accuracy: 0.0000e+00 - val_loss: 0.0032
# Epoch 45/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0137 - val_accuracy: 0.0000e+00 - val_loss: 0.0038
# Epoch 46/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0190 - val_accuracy: 0.0000e+00 - val_loss: 0.0025
# Epoch 47/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0184 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 48/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0146 - val_accuracy: 0.0000e+00 - val_loss: 0.0017
# Epoch 49/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0143 - val_accuracy: 0.0000e+00 - val_loss: 0.0037
# Epoch 50/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0150 - val_accuracy: 0.0000e+00 - val_loss: 0.0020

# %%
y_pred = model.predict(x_test)

y_prediction = scaler.inverse_transform(y_pred.reshape(-1,1))
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
plt.figure(figsize=(6,4))
plt.plot(y_test, label = 'actual value', color = 'red', linewidth = 2)
plt.plot(y_prediction, label = 'predicted value', color = 'blue', linewidth = 2)
plt.title('Tesla Stock Price Prediction')
plt.xlabel('sample index')
plt.ylabel('Tesla Stock price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_prediction)
print("Mean Absolute Error (MAE):", mae)

mse = mean_squared_error(y_test, y_prediction)
print("Mean Squared Error (MSE):", mse)

r2 = r2_score(y_test, y_prediction)
print("R-squared (R2) Score:", r2 *100)
# Out:
# Mean Absolute Error (MAE): 9.634892809277488
# Mean Squared Error (MSE): 203.1610855000976
# R-squared (R2) Score: 99.68921321600051

# %%
plt.plot(cont1.history['loss'], label='Training Loss')
plt.plot(cont1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
